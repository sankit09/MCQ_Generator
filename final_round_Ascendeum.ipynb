# %% [markdown]
# <a href="https://colab.research.google.com/github/sankit09/MCQ_Generator/blob/main/final_round_Ascendeum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries

import numpy as np
import pandas as pd

# %%
# Read the CSV
df = pd.read_csv("/content/adtech_click_log.csv")

# %%
Q1: Identify the top drivers of CTR (Click-Through Rate)

 Q2: Suggest two data-backed ideas to either:
      Improve overall CTR Reduce wasted ad spend (i.e., where we’re spending but not getting clicks)

# %%
# top 5 row
df.head()
# Out:
#              timestamp  ad_id campaign_id publisher_id device_type country  \
# 0  2025-04-06 16:34:48  ad_39      camp_1       pub_12      mobile      US
# 1  2025-04-09 00:40:14  ad_29      camp_9        pub_8      tablet      US
# 2  2025-04-07 18:49:03  ad_15      camp_3        pub_4      tablet      UK
# 3  2025-04-10 05:56:34  ad_43      camp_9        pub_7     desktop      IN
# 4  2025-04-10 02:49:06   ad_8     camp_10        pub_3      mobile      IN
#
#    bid_price  clicked
# 0       2.46        0
# 1       1.91        0
# 2       1.92        0
# 3       2.88        0
# 4       1.88        0

# %%
# lower 5 rows
df.tail()
# Out:
#                  timestamp  ad_id campaign_id publisher_id device_type  \
# 49995  2025-04-10 11:43:19  ad_26      camp_3        pub_5      mobile
# 49996  2025-04-05 16:09:31  ad_22     camp_10       pub_12      tablet
# 49997  2025-04-11 11:14:31  ad_15      camp_7       pub_12      mobile
# 49998  2025-04-11 16:49:04   ad_9      camp_6       pub_13      mobile
# 49999  2025-04-10 11:17:20  ad_26     camp_10       pub_20      mobile
#
#       country  bid_price  clicked
# 49995      US       4.88        0
# 49996      SG       2.05        0
# 49997      SG       1.66        0
# 49998      AU       2.02        0
# 49999      SG       0.96        0

# %%
# shape of the data
df.shape
# Out:
# (50000, 8)

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     50000 non-null  object
#  1   ad_id         50000 non-null  object
#  2   campaign_id   50000 non-null  object
#  3   publisher_id  50000 non-null  object
#  4   device_type   50000 non-null  object
#  5   country       50000 non-null  object
#  6   bid_price     50000 non-null  float64
#  7   clicked       50000 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.1+ MB

# %%
# statistical idea
df.describe()
# Out:
#           bid_price       clicked
# count  50000.000000  50000.000000
# mean       2.757574      0.064480
# std        1.299826      0.245609
# min        0.500000      0.000000
# 25%        1.630000      0.000000
# 50%        2.750000      0.000000
# 75%        3.880000      0.000000
# max        5.000000      1.000000

# %%
# checking Null Values

df.isnull().sum()
# Out:
# timestamp       0
# ad_id           0
# campaign_id     0
# publisher_id    0
# device_type     0
# country         0
# bid_price       0
# clicked         0
# dtype: int64

# %%
# check the column name

df.columns
# Out:
# Index(['timestamp', 'ad_id', 'campaign_id', 'publisher_id', 'device_type',
#        'country', 'bid_price', 'clicked'],
#       dtype='object')

# %% [markdown]
# # Q1: Identify the top drivers of CTR (Click-Through Rate)

# %%
import pandas as pd



# Compute CTR per feature
def compute_ctr(df, groupby_col):
    summary = df.groupby(groupby_col).agg(
        impressions=('clicked', 'count'),
        clicks=('clicked', 'sum')
    ).reset_index()
    summary['CTR (%)'] = (summary['clicks'] / summary['impressions']) * 100
    return summary.sort_values(by='CTR (%)', ascending=False)

# By Device
ctr_device = compute_ctr(df, 'device_type').reindex()
# By Country
ctr_country = compute_ctr(df, 'country').reindex()
# By Publisher (platform)
ctr_publisher = compute_ctr(df, 'publisher_id').reindex()
# By Campaign
ctr_campaign = compute_ctr(df, 'campaign_id').reindex()

# %%
ctr_device
# Out:
#   device_type  impressions  clicks   CTR (%)
# 1      mobile        29985    2144  7.150242
# 0     desktop        14960     812  5.427807
# 2      tablet         5055     268  5.301682

# %% [markdown]
# ### Device Type: Mobile users might show higher CTRs due to more casual browsing or app-focused ads.

# %%
ctr_country
# Out:
#   country  impressions  clicks   CTR (%)
# 1      IN        20037    1356  6.767480
# 3      UK         7633     513  6.720818
# 2      SG         7436     484  6.508876
# 4      US         9915     588  5.930408
# 0      AU         4979     283  5.683872

# %% [markdown]
# ### Country: Certain countries could drive more engagement due to cultural differences or relevance of ads.

# %%
ctr_publisher
# Out:
#    publisher_id  impressions  clicks   CTR (%)
# 18        pub_8         2524     182  7.210777
# 0         pub_1         2582     184  7.126259
# 15        pub_5         2507     176  7.020343
# 19        pub_9         2458     165  6.712775
# 5        pub_14         2576     171  6.638199
# 7        pub_16         2517     167  6.634883
# 2        pub_11         2520     167  6.626984
# 1        pub_10         2478     163  6.577885
# 14        pub_4         2453     159  6.481859
# 9        pub_18         2508     161  6.419458
# 11        pub_2         2518     161  6.393963
# 10       pub_19         2430     155  6.378601
# 12       pub_20         2476     157  6.340872
# 8        pub_17         2500     156  6.240000
# 4        pub_13         2549     157  6.159278
# 3        pub_12         2530     155  6.126482
# 13        pub_3         2417     148  6.123293
# 6        pub_15         2525     150  5.940594
# 16        pub_6         2460     146  5.934959
# ...

# %% [markdown]
# Publisher: Platforms (e.g., apps vs website like here publisher_id) matter. Some publishers perform way better than others

# %%
ctr_campaign
# Out:
#   campaign_id  impressions  clicks   CTR (%)
# 9      camp_9         5049     345  6.833036
# 3      camp_3         4943     337  6.817722
# 0      camp_1         4947     325  6.569638
# 2      camp_2         4987     324  6.496892
# 4      camp_4         5012     325  6.484437
# 6      camp_6         5019     324  6.455469
# 1     camp_10         5050     326  6.455446
# 8      camp_8         4974     312  6.272618
# 5      camp_5         4993     312  6.248748
# 7      camp_7         5026     294  5.849582

# %% [markdown]
# # 2.
# Q2: Suggest two data-backed ideas to either:
#       Improve overall CTR Reduce wasted ad spend (i.e., where we’re spending but not getting clicks)

# %%
# high_perf = compute_ctr(df, 'country')
# high_perf = high_perf[high_perf['CTR (%)'] > 2]
# #

# %%
# high_perf
# Out:
#   country  impressions  clicks   CTR (%)
# 1      IN        20037    1356  6.767480
# 3      UK         7633     513  6.720818
# 2      SG         7436     484  6.508876
# 4      US         9915     588  5.930408
# 0      AU         4979     283  5.683872

# %%
Recommendation 1: Shift Budget to High-CTR Device Types and Publishers
Why:

Mobile devices deliver the highest CTR: 7.15% (vs Desktop: 5.42%, Tablet: 5.30%)

Top publishers like pub_8, pub_1, pub_5 achieve CTR > 7%

Action:

Allocate more budget to mobile-first campaigns

Prioritize bidding on high-performing publishers (e.g., pub_8, pub_5)

Consider optimizing mobile creatives further since this segment is already responsive

# example : "Mobile users + pub_8 = 7.21% CTR — this is a top-performing combo worth scaling."

# %%
Recommendation 2: Cut Spend from Underperforming Segments (Low ROI)
Why:

Campaigns like camp_7 and camp_5 have CTRs below 6.3%

Countries like AU (5.68% CTR) and SG (6.50%) trail significantly behind IN/UK

Some publishers (e.g., pub_7) are below average despite high impressions

Action:

Pause or test reduced bids for low-CTR segments (e.g., pub_7, camp_7, AU)

Reinvest that budget in India (6.76% CTR) and UK (6.72%), which outperform while still having volume

# Example: Reducing spend in Australia (CTR = 5.68%) and scaling in India (CTR = 6.76%) could improve ROI instantly.
